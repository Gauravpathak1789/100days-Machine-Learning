# %%
id 
title
release_date
overview
popularity
vote_average
vote_count

# %%
import pandas as pd
import requests

# %%
response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=86c3a50e51a01bf18f704e7155605197&language=en-US&page=1")

# %%
df=pd.DataFrame(response.json()['results'])[["id","title","release_date","overview","popularity","vote_average","vote_count"]]

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...     112.102
# 1  Spanning the years 1945 to 1955, a chronicle o...     102.418
# 2  In the continuing saga of the Corleone crime f...      78.542
# 3  The true story of how businessman Oskar Schind...      62.139
# 4  The defense and the prosecution have rested an...      58.112
#
#    vote_average  vote_count
# 0         8.711       25430
# 1         8.708       19357
# 2         8.592       11675
# 3         8.572       15046
# 4         8.547        7980

# %%
df.shape
# Out:
# (20, 7)

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,458):
    response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=86c3a50e51a01bf18f704e7155605197&language=en-US&page={}".format(i))
    temp_df=pd.DataFrame(response.json()['results'])[["id","title","release_date","overview","popularity","vote_average","vote_count"]]
    df=df.append(temp_df,ignore_index=True) #instead of append we should use concat
# Out:
# C:\Users\Gaurav Pathak\AppData\Local\Temp\ipykernel_145620\3547299228.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\Gaurav Pathak\AppData\Local\Temp\ipykernel_145620\3547299228.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\Gaurav Pathak\AppData\Local\Temp\ipykernel_145620\3547299228.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\Gaurav Pathak\AppData\Local\Temp\ipykernel_145620\3547299228.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...     112.102
# 1  Spanning the years 1945 to 1955, a chronicle o...     102.418
# 2  In the continuing saga of the Corleone crime f...      78.542
# 3  The true story of how businessman Oskar Schind...      62.139
# 4  The defense and the prosecution have rested an...      58.112
#
#    vote_average  vote_count
# 0         8.711       25430
# 1         8.708       19357
# 2         8.592       11675
# 3         8.572       15046
# 4         8.547        7980

# %%
df.shape
# Out:
# (9123, 7)

# %%
df.to_csv("api_movies.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9123 entries, 0 to 9122
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9123 non-null   int64
#  1   title         9123 non-null   object
#  2   release_date  9123 non-null   object
#  3   overview      9123 non-null   object
#  4   popularity    9123 non-null   float64
#  5   vote_average  9123 non-null   float64
#  6   vote_count    9123 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 499.0+ KB
